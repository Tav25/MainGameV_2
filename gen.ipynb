# %%
count = 10
varName = 'topCardTexture_'
texName = varName

# %%
texExport = ''
texExport2 = ''
arrayExp = ''
i=0
d = 0
while i <= count-1:
    d +=1
    if d == 10:
        per = '\n'
        d = 0
    else:
        per = '' 
    texExport = texExport + varName +str(i)+', ' + per
    texExport2 = texExport2 + 'Textures.findFirst(\''+texName +str(i)+'\'), ' +per
    arrayExp = arrayExp + varName +str(i)+', '  +per
    i += 1

        
# print(texExport)

# %%
texExport2 = ''
arrayExp = ''
i=0
d = 0
while i <= count-1:
    d +=1
    if d == 10:
        per = '\n'
        d = 0
    else:
        per = '' 
    texExport = texExport + varName +str(i)+', ' + per
    texExport2 = texExport2 + 'Textures.findFirst(\''+texName +str(i)+'\'), ' +per
    arrayExp = arrayExp + varName +str(i)+', '  +per
    i += 1

        
# print(texExport)

# %%
x = f'''const [
{texExport}
] = await Promise.all([
{texExport2}
])

let texArray = [
{arrayExp}
] // {i} textures
'''

# %%
print(x)
# Out:
# const [
# topCardTexture_0, topCardTexture_1, topCardTexture_2, topCardTexture_3, topCardTexture_4, topCardTexture_5, topCardTexture_6, topCardTexture_7, topCardTexture_8, topCardTexture_9,
# topCardTexture_0, topCardTexture_1, topCardTexture_2, topCardTexture_3, topCardTexture_4, topCardTexture_5, topCardTexture_6, topCardTexture_7, topCardTexture_8, topCardTexture_9,
#
# ] = await Promise.all([
# Textures.findFirst('topCardTexture_0'), Textures.findFirst('topCardTexture_1'), Textures.findFirst('topCardTexture_2'), Textures.findFirst('topCardTexture_3'), Textures.findFirst('topCardTexture_4'), Textures.findFirst('topCardTexture_5'), Textures.findFirst('topCardTexture_6'), Textures.findFirst('topCardTexture_7'), Textures.findFirst('topCardTexture_8'), Textures.findFirst('topCardTexture_9'),
#
# ])
#
# let texArray = [
# topCardTexture_0, topCardTexture_1, topCardTexture_2, topCardTexture_3, topCardTexture_4, topCardTexture_5, topCardTexture_6, topCardTexture_7, topCardTexture_8, topCardTexture_9,
#
# ] // 10 textures

# %%
count = 4
varName = 'topCard_'
texName = '_'+varName

# %%
texExport = ''
texExport2 = ''
varExport = ''
arrayExp = ''
objExport = ''
i=0
while i <= count-1:
    varExport = varExport + ' '+ varName +str(i) 
    texExport = texExport + varName +str(i)+', '+texName +str(i)+', \n'
    texExport2 = texExport2 + 'Scene.root.findFirst(\''+varName +str(i)+'\'), Materials.findFirst(\''+texName +str(i)+'\'),\n'
    # arrayExp = arrayExp + varName +str(i)+', '
    i += 1
i=0
while i <= count-1:
    objExport = objExport + "let "+ varName +str(i)+"Obj = new Osc.OnScene("+ varName +str(i)+","+ texName +str(i)+", texArray)\n" 
    i += 1
# print(texExport)

# %%
x = f'''//{varExport}

const [
{texExport}] = await Promise.all([
{texExport2}]) // {i} obj and mat

let texArray = [{arrayExp}]

{objExport}

'''

# %%
print(x)
# Out:
# // topCard_0 topCard_1 topCard_2 topCard_3
#
# const [
# topCard_0, _topCard_0,
# topCard_1, _topCard_1,
# topCard_2, _topCard_2,
# topCard_3, _topCard_3,
# ] = await Promise.all([
# Scene.root.findFirst('topCard_0'), Materials.findFirst('_topCard_0'),
# Scene.root.findFirst('topCard_1'), Materials.findFirst('_topCard_1'),
# Scene.root.findFirst('topCard_2'), Materials.findFirst('_topCard_2'),
# Scene.root.findFirst('topCard_3'), Materials.findFirst('_topCard_3'),
# ]) // 4 obj and mat
#
# let texArray = []
#
# let topCard_0Obj = new Osc.OnScene(topCard_0,_topCard_0, texArray)
# let topCard_1Obj = new Osc.OnScene(topCard_1,_topCard_1, texArray)
# let topCard_2Obj = new Osc.OnScene(topCard_2,_topCard_2, texArray)
# let topCard_3Obj = new Osc.OnScene(topCard_3,_topCard_3, texArray)

# %%
const[mainCard0] = await Promise.all([Scene.root.findFirst("mainCard0")])
const[_indexFace0] = await Promise.all([Materials.findFirst("_indexFace0")])
const[_indexBack0] = await Promise.all([Materials.findFirst("_indexBack0")])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26820/52842606.py in <module>
# ----> 1 const[mainCard0] = await Promise.all([Scene.root.findFirst("mainCard0")])
#       2 const[_indexFace0] = await Promise.all([Materials.findFirst("_indexFace0")])
#       3 const[_indexBack0] = await Promise.all([Materials.findFirst("_indexBack0")])
#
# NameError: name 'Promise' is not defined
